# %% [markdown]
# <a href="https://colab.research.google.com/github/tahama2000/aleph/blob/main/CHEM539_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHEM539-Assignment2
# ### Taha M. Mahmoud

# %% [markdown]
# Q: Write a Python program to compute the matrix multiplication of two matrices, A and B as C=AB. A and B are 20X20 matrices containing random numbers between 0 and 1000. Once done, push this into your git repository, which was developed in the class, and make a pull request.
#
# Alternative: In case you are having technical difficulties, you can also (a) submit a link to your git repo, (b) write the code in google collab and share the jupyter notebook with the instructor.

# %% [markdown]
# #Answer

# %% [markdown]
# ### Steps
# * Import liberaries
# * Create Generate random matrix function
# * Create Multiply Function
# * Test functions
# * Answer the question

# %%
# Import liberaries
import numpy as np


# Create Generate random matrix function
def generate_random_matrix(n, m):
    matrix_x = matrix_a= np.random.randint(1, high=1000, size=(n,m), dtype='l')
    return matrix_x


# Create Multiply Function
def multiply(matrix_a, matrix_b):
    result = np.dot(matrix_a, matrix_b)
    return result


## Test Functions
# Test
matrix_a = [3,4]
matrix_b = [1,2]

# Multiply the matrices and print the result
matrix_c = multiply(matrix_a, matrix_b)
print("======= Test Functions ======")
print("matrix_a = ", matrix_a)
print("matrix_b = ", matrix_b)

print("matrix_a . matrix_b = ")
print(matrix_c)
print("\n")


print("======= Answer the question ======")
print("\n")
## Answer the question
n=20 # number of rows
m=20 # number of columns


## Generating Matrix A as 20X20
matrix_a= generate_random_matrix(n,m)
print("Matrix A")
print(matrix_a)
print("\n")


# Generating Matrix B as 20X20
matrix_b= generate_random_matrix(n,m)
print("Matrix B")
print(matrix_b)
print("\n")


# Claculate Matrix_A . Matrix_B
matrix_c = multiply(matrix_a, matrix_b)
print("matrix_a . matrix_b = ")
print(matrix_c)
# Out:
# ======= Test Functions ======
# matrix_a =  [3, 4]
# matrix_b =  [1, 2]
# matrix_a . matrix_b =
# 11
#
#
# ======= Answer the question ======
#
#
# Matrix A
# [[870   7 803 610 637 651 654 561 175 489 299 678 249 197 886 946 405 544
#   915 915]
#  [340 928  46 995 443 379 811 547  38 486 634 180 861 108 357 879 187 579
#   602 246]
#  [672  25 516 844 659 553 633 560 897 233 899 897 120 674 956 181 986 988
#   652 556]
#  [923 286 914 265 887  63  30 765 156 428 458 691 225 954 829 132 158  82
#   243 655]
#  [135 451 305 670 990 979 252 824  16  98 705 201 581 131 602 124 333 829
#   554 417]
#  [734 105 828  59 452 789 989 201 947 444 412 291 797  52 400 211 459 763
#   204  32]
#  [524 998 891 632 569 128 594 743 996 565 855 229 510 126 641  91 240 396
#   990 440]
#  [678 119 802 416 694 791 865 483 362 975 959 470 519 768 553 865 889 369
#   787 597]
#  [  4 789 251 966 793 122 353 801 263 334 240 232 809 555 485 990 186 721
#   228 490]
# ...
